# %% [markdown]
# <a href="https://colab.research.google.com/github/bmaier/colpali-cookbooks/blob/main/examples/pdf_docx_image_rag_colqwen2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ColQwen2: One model for your whole RAG pipeline with adapter hot-swapping 🔥
#
# [![Colab](https://img.shields.io/badge/Open_in_Colab-F9AB00?logo=googlecolab&logoColor=fff&style=for-the-badge)](https://colab.research.google.com/github/tonywu71/colpali-cookbooks/blob/main/examples/run_e2e_rag_colqwen2_with_adapter_hot_swapping.ipynb)
# [![GitHub](https://img.shields.io/badge/ColPali_Cookbooks-100000?style=for-the-badge&logo=github&logoColor=white)](https://github.com/tonywu71/colpali-cookbooks)
# [![arXiv](https://img.shields.io/badge/arXiv-2407.01449-b31b1b.svg?style=for-the-badge)](https://arxiv.org/abs/2407.01449)
# [![Hugging Face](https://img.shields.io/badge/Vidore-FFD21E?style=for-the-badge&logo=huggingface&logoColor=000)](https://huggingface.co/vidore)
# [![X](https://img.shields.io/badge/Thread-%23000000?style=for-the-badge&logo=X&logoColor=white)](https://x.com/tonywu_71/status/1809183824464560138)
#
# ## Introduction
#
# With our new model [*ColQwen2*](https://x.com/ManuelFaysse/status/1839657285053788483), we propose to leverage VLMs to construct efficient multi-vector embeddings in the visual space for document retrieval. By feeding the ViT output patches from [Qwen2-VL](https://doi.org/10.48550/arXiv.2409.12191) to a linear projection, we create a multi-vector representation of documents. We train the model to maximize the similarity between these document embeddings and the query embeddings, following the ColBERT method.
#
# Using ColQwen2 removes the need for potentially complex and brittle layout recognition and OCR pipelines with a single model that can take into account both the textual and visual content (layout, charts, ...) of a document.
#
# Because ColQwen2 was trained with [LoRA](https://huggingface.co/docs/peft/main/en/conceptual_guides/lora), you can easily use adapter hot-swapping to switch between:
# 1. Using the pre-trained adapter for creating the document embeddings used for retrieval
# 2. Unload the adapter and use the backbone VLM for image-grounded generation.
#
# ![E2E RAG example](https://github.com/tonywu71/colpali-cookbooks/blob/main/assets/rag/e2e_rag_with_colqwen2_diagram.jpeg?raw=true)
#
# With this method, you can use a single model for your whole RAG pipeline, hence saving the need of having multiple models that take up a lot of VRAM! 😍
#
# ## Hardware Requirements
#
# You can run it on Google Colab (using the free-tier T4 GPU) or locally (tested on a M2 Pro Mac).
#
# ## Important ⚠️
# The Qwen2-VL model used in ColQwen2 is the [`Qwen/Qwen2-VL-2B-Instruct`](https://huggingface.co/Qwen/Qwen2-VL-2B-Instruct) checkpoint, which is relatively small compared to other VLMs available at the time of writing. Based on my experiments and findings from the [Qwen2-VL paper](https://doi.org/10.48550/arXiv.2409.12191), the 2B version performs well for text-heavy documents (e.g., DocVQA) but falls short compared to larger checkpoints when it comes to understanding complex charts (e.g., ChartQA and InfoVQA).
#
# | Benchmark   | Qwen2-VL-72B | Qwen2-VL-7B | Qwen2-VL-2B (used in ColQwen2) |
# |-------------|--------------|-------------|--------------------------------|
# | DocVQA      | **96.5**     | 94.5        | 90.1                           |
# | ChartQA     | **88.3**     | 83.0        | 73.5                           |
# | InfoVQA     | **84.5**     | 76.5        | 65.5                           |
#
# Thus, if you need stronger reasoning capabilities for your RAG, I recommend using using ColQwen2 for retrieval and a larger VLM for generation, e.g. [`Qwen/Qwen2-VL-72B-Instruct`](https://huggingface.co/Qwen/Qwen2-VL-72B-Instruct) or [`mistralai/Pixtral-12B-2409`](https://huggingface.co/mistralai/Pixtral-12B-2409). While this approach uses more VRAM, separate models offer more flexibility for the generation part.

# %% [markdown]
# ## Imports

# %% [markdown]
# This notebook leverages [`colpali-engine`](https://github.com/illuin-tech/colpali), the official implementation of ColPali and ColQwen2. This package also contains the training code (processor, collator, trainer...) for fine-tuning these models on your own dataset.

# %%
# !pip install -q -U "colpali-engine>=0.3.1,<0.4.0" requests
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 40.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 66.0 MB/s eta 0:00:00
#   Building wheel for gputil (setup.py) ... done

# %%
from io import BytesIO
from typing import Any, List, cast

import requests
import torch
from colpali_engine.models import ColQwen2, ColQwen2Processor
from colpali_engine.utils.torch_utils import get_torch_device
from IPython.display import display
from peft import LoraConfig
from PIL import Image
from transformers.models.qwen2_vl import Qwen2VLForConditionalGeneration, Qwen2VLProcessor

# %% [markdown]
# ## A few custom utils

# %%
def load_image_from_url(url: str) -> Image.Image:
    """
    Load a PIL image from a valid URL.
    """
    response = requests.get(url)
    return Image.open(BytesIO(response.content))


def scale_image(image: Image.Image, new_height: int = 1024) -> Image.Image:
    """
    Scale an image to a new height while maintaining the aspect ratio.
    """
    width, height = image.size
    aspect_ratio = width / height
    new_width = int(new_height * aspect_ratio)

    scaled_image = image.resize((new_width, new_height))

    return scaled_image

# %%
# !pip install docx2pdf
# Out:
# Collecting docx2pdf
#   Downloading docx2pdf-0.1.8-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from docx2pdf) (4.67.1)
# Downloading docx2pdf-0.1.8-py3-none-any.whl (6.7 kB)
# Installing collected packages: docx2pdf
# Successfully installed docx2pdf-0.1.8

# %%
# !pip install pymupdf
# Out:
# Collecting pymupdf
#   Downloading pymupdf-1.25.3-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.25.3-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (20.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 80.1 MB/s eta 0:00:00
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.25.3

# %%
# !apt-get update
# !apt-get install -y libreoffice-writer --fix-missing
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [66.7 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,309 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,665 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,606 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,230 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,907 kB]
# Get:17 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,653 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,523 kB]
# Get:19 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [57.8 kB]
# Fetched 21.4 MB in 5s (4,230 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   apparmor dictionaries-common fonts-liberation2 fonts-opensymbol hunspell-en-us libabsl20210324
#   libabw-0.1-1 libclucene-contribs1v5 libclucene-core1v5 libe-book-0.1-1 libeot0 libepubgen-0.1-1
#   libetonyek-0.1-1 libexttextcat-2.0-0 libexttextcat-data libgpgme11 libgpgmepp6 libharfbuzz-icu0
#   libhunspell-1.7-0 libhyphen0 liblangtag-common liblangtag1 libmhash2 libmwaw-0.3-3
#   libmythes-1.2-0 libodfgen-0.1-1 liborcus-0.17-0 liborcus-parser-0.17-0 libraptor2-0 librasqal3
#   librdf0 libreoffice-base-core libreoffice-common libreoffice-core libreoffice-math
#   libreoffice-style-colibre librevenge-0.0-0 libtext-iconv-perl libuno-cppu3
#   libuno-cppuhelpergcc3-3 libuno-purpenvhelpergcc3-3 libuno-sal3 libuno-salhelpergcc3-3
#   libwpd-0.10-10 libwpg-0.3-3 libwps-0.4-4 libxmlsec1 libxmlsec1-nss libyajl2 poppler-data
#   python3-uno uno-libs-private ure
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils ispell | aspell | hunspell wordlist hunspell
#   openoffice.org-hunspell | openoffice.org-core raptor2-utils rasqal-utils
#   librdf-storage-postgresql librdf-storage-mysql librdf-storage-sqlite librdf-storage-virtuoso
#   redland-utils libreoffice-base gstreamer1.0-plugins-base gstreamer1.0-plugins-good
#   gstreamer1.0-plugins-ugly gstreamer1.0-plugins-bad gstreamer1.0-libav fonts-crosextra-caladea
#   fonts-crosextra-carlito libreoffice-java-common default-jre | java8-runtime | jre poppler-utils
#   ghostscript fonts-japanese-mincho | fonts-ipafont-mincho fonts-japanese-gothic
#   | fonts-ipafont-gothic fonts-arphic-ukai fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
#   apparmor dictionaries-common fonts-liberation2 fonts-opensymbol hunspell-en-us libabsl20210324
#   libabw-0.1-1 libclucene-contribs1v5 libclucene-core1v5 libe-book-0.1-1 libeot0 libepubgen-0.1-1
#   libetonyek-0.1-1 libexttextcat-2.0-0 libexttextcat-data libgpgme11 libgpgmepp6 libharfbuzz-icu0
#   libhunspell-1.7-0 libhyphen0 liblangtag-common liblangtag1 libmhash2 libmwaw-0.3-3
#   libmythes-1.2-0 libodfgen-0.1-1 liborcus-0.17-0 liborcus-parser-0.17-0 libraptor2-0 librasqal3
#   librdf0 libreoffice-base-core libreoffice-common libreoffice-core libreoffice-math
#   libreoffice-style-colibre libreoffice-writer librevenge-0.0-0 libtext-iconv-perl libuno-cppu3
#   libuno-cppuhelpergcc3-3 libuno-purpenvhelpergcc3-3 libuno-sal3 libuno-salhelpergcc3-3
#   libwpd-0.10-10 libwpg-0.3-3 libwps-0.4-4 libxmlsec1 libxmlsec1-nss libyajl2 poppler-data
#   python3-uno uno-libs-private ure
# 0 upgraded, 54 newly installed, 0 to remove and 25 not upgraded.
# Need to get 92.5 MB of archives.
# After this operation, 309 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 poppler-data all 0.4.11-1 [2,171 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtext-iconv-perl amd64 1.7-7build3 [14.3 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 apparmor amd64 3.0.4-2ubuntu2.4 [598 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 dictionaries-common all 1.28.14 [185 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-liberation2 all 2.1.5-1 [1,614 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 fonts-opensymbol all 2:102.12+LibO7.3.7-0ubuntu0.22.04.8 [103 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 hunspell-en-us all 1:2020.12.07-2 [280 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libabsl20210324 amd64 0~20210324.2-2 [387 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 librevenge-0.0-0 amd64 0.0.4-6ubuntu7 [209 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libabw-0.1-1 amd64 0.1.3-1build3 [102 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclucene-core1v5 amd64 2.3.3.4+dfsg-1ubuntu5 [530 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclucene-contribs1v5 amd64 2.3.3.4+dfsg-1ubuntu5 [96.7 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblangtag-common all 0.6.3-2ubuntu1 [193 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblangtag1 amd64 0.6.3-2ubuntu1 [53.8 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libe-book-0.1-1 amd64 0.1.3-2build2 [148 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libeot0 amd64 0.01-5build2 [28.5 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libepubgen-0.1-1 amd64 0.1.1-1ubuntu5 [120 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libetonyek-0.1-1 amd64 0.1.10-3build1 [637 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libexttextcat-data all 3.4.5-1build2 [179 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libexttextcat-2.0-0 amd64 3.4.5-1build2 [13.7 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgpgme11 amd64 1.16.0-1.2ubuntu4.2 [136 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgpgmepp6 amd64 1.16.0-1.2ubuntu4.2 [109 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libharfbuzz-icu0 amd64 2.7.4-1ubuntu3.2 [5,890 B]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhunspell-1.7-0 amd64 1.7.0-4build1 [175 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhyphen0 amd64 2.8.8-7build2 [28.2 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmhash2 amd64 0.9.9.9-9build2 [95.9 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmwaw-0.3-3 amd64 0.3.21-1build1 [2,375 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmythes-1.2-0 amd64 2:1.2.4-4build1 [9,352 B]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libodfgen-0.1-1 amd64 0.1.8-2build2 [245 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 liborcus-parser-0.17-0 amd64 0.17.2-2 [107 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 liborcus-0.17-0 amd64 0.17.2-2 [393 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libyajl2 amd64 2.1.0-3ubuntu0.22.04.1 [21.0 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libraptor2-0 amd64 2.0.15-0ubuntu4 [172 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 librasqal3 amd64 0.9.33-0.2ubuntu1 [193 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 librdf0 amd64 1.0.17-1.1ubuntu3 [106 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-style-colibre all 1:7.3.7-0ubuntu0.22.04.8 [1,294 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-sal3 amd64 1:7.3.7-0ubuntu0.22.04.8 [197 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-salhelpergcc3-3 amd64 1:7.3.7-0ubuntu0.22.04.8 [17.0 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-cppu3 amd64 1:7.3.7-0ubuntu0.22.04.8 [87.8 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 uno-libs-private amd64 1:7.3.7-0ubuntu0.22.04.8 [232 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-cppuhelpergcc3-3 amd64 1:7.3.7-0ubuntu0.22.04.8 [343 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-purpenvhelpergcc3-3 amd64 1:7.3.7-0ubuntu0.22.04.8 [15.8 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ure amd64 1:7.3.7-0ubuntu0.22.04.8 [1,312 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-common all 1:7.3.7-0ubuntu0.22.04.8 [23.4 MB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmlsec1 amd64 1.2.33-1build2 [139 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmlsec1-nss amd64 1.2.33-1build2 [67.7 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-core amd64 1:7.3.7-0ubuntu0.22.04.8 [40.4 MB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-base-core amd64 1:7.3.7-0ubuntu0.22.04.8 [974 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-math amd64 1:7.3.7-0ubuntu0.22.04.8 [596 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwpd-0.10-10 amd64 0.10.3-2build1 [209 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwpg-0.3-3 amd64 0.3.3-1build3 [49.9 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwps-0.4-4 amd64 0.4.12-2build1 [812 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-writer amd64 1:7.3.7-0ubuntu0.22.04.8 [10.3 MB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-uno amd64 1:7.3.7-0ubuntu0.22.04.8 [148 kB]
# Fetched 92.5 MB in 3s (26.6 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package poppler-data.
# (Reading database ... 124926 files and directories currently installed.)
# Preparing to unpack .../00-poppler-data_0.4.11-1_all.deb ...
# Unpacking poppler-data (0.4.11-1) ...
# Selecting previously unselected package libtext-iconv-perl.
# Preparing to unpack .../01-libtext-iconv-perl_1.7-7build3_amd64.deb ...
# Unpacking libtext-iconv-perl (1.7-7build3) ...
# Selecting previously unselected package apparmor.
# Preparing to unpack .../02-apparmor_3.0.4-2ubuntu2.4_amd64.deb ...
# Unpacking apparmor (3.0.4-2ubuntu2.4) ...
# Selecting previously unselected package dictionaries-common.
# Preparing to unpack .../03-dictionaries-common_1.28.14_all.deb ...
# Adding 'diversion of /usr/share/dict/words to /usr/share/dict/words.pre-dictionaries-common by dictionaries-common'
# Unpacking dictionaries-common (1.28.14) ...
# Selecting previously unselected package fonts-liberation2.
# Preparing to unpack .../04-fonts-liberation2_2.1.5-1_all.deb ...
# Unpacking fonts-liberation2 (2.1.5-1) ...
# Selecting previously unselected package fonts-opensymbol.
# Preparing to unpack .../05-fonts-opensymbol_2%3a102.12+LibO7.3.7-0ubuntu0.22.04.8_all.deb ...
# Unpacking fonts-opensymbol (2:102.12+LibO7.3.7-0ubuntu0.22.04.8) ...
# Selecting previously unselected package hunspell-en-us.
# Preparing to unpack .../06-hunspell-en-us_1%3a2020.12.07-2_all.deb ...
# Unpacking hunspell-en-us (1:2020.12.07-2) ...
# Selecting previously unselected package libabsl20210324:amd64.
# Preparing to unpack .../07-libabsl20210324_0~20210324.2-2_amd64.deb ...
# Unpacking libabsl20210324:amd64 (0~20210324.2-2) ...
# Selecting previously unselected package librevenge-0.0-0:amd64.
# Preparing to unpack .../08-librevenge-0.0-0_0.0.4-6ubuntu7_amd64.deb ...
# Unpacking librevenge-0.0-0:amd64 (0.0.4-6ubuntu7) ...
# Selecting previously unselected package libabw-0.1-1:amd64.
# Preparing to unpack .../09-libabw-0.1-1_0.1.3-1build3_amd64.deb ...
# Unpacking libabw-0.1-1:amd64 (0.1.3-1build3) ...
# Selecting previously unselected package libclucene-core1v5:amd64.
# Preparing to unpack .../10-libclucene-core1v5_2.3.3.4+dfsg-1ubuntu5_amd64.deb ...
# Unpacking libclucene-core1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Selecting previously unselected package libclucene-contribs1v5:amd64.
# Preparing to unpack .../11-libclucene-contribs1v5_2.3.3.4+dfsg-1ubuntu5_amd64.deb ...
# Unpacking libclucene-contribs1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Selecting previously unselected package liblangtag-common.
# Preparing to unpack .../12-liblangtag-common_0.6.3-2ubuntu1_all.deb ...
# Unpacking liblangtag-common (0.6.3-2ubuntu1) ...
# Selecting previously unselected package liblangtag1:amd64.
# Preparing to unpack .../13-liblangtag1_0.6.3-2ubuntu1_amd64.deb ...
# Unpacking liblangtag1:amd64 (0.6.3-2ubuntu1) ...
# Selecting previously unselected package libe-book-0.1-1:amd64.
# Preparing to unpack .../14-libe-book-0.1-1_0.1.3-2build2_amd64.deb ...
# Unpacking libe-book-0.1-1:amd64 (0.1.3-2build2) ...
# Selecting previously unselected package libeot0:amd64.
# Preparing to unpack .../15-libeot0_0.01-5build2_amd64.deb ...
# Unpacking libeot0:amd64 (0.01-5build2) ...
# Selecting previously unselected package libepubgen-0.1-1:amd64.
# Preparing to unpack .../16-libepubgen-0.1-1_0.1.1-1ubuntu5_amd64.deb ...
# Unpacking libepubgen-0.1-1:amd64 (0.1.1-1ubuntu5) ...
# Selecting previously unselected package libetonyek-0.1-1:amd64.
# Preparing to unpack .../17-libetonyek-0.1-1_0.1.10-3build1_amd64.deb ...
# Unpacking libetonyek-0.1-1:amd64 (0.1.10-3build1) ...
# Selecting previously unselected package libexttextcat-data.
# Preparing to unpack .../18-libexttextcat-data_3.4.5-1build2_all.deb ...
# Unpacking libexttextcat-data (3.4.5-1build2) ...
# Selecting previously unselected package libexttextcat-2.0-0:amd64.
# Preparing to unpack .../19-libexttextcat-2.0-0_3.4.5-1build2_amd64.deb ...
# Unpacking libexttextcat-2.0-0:amd64 (3.4.5-1build2) ...
# Selecting previously unselected package libgpgme11:amd64.
# Preparing to unpack .../20-libgpgme11_1.16.0-1.2ubuntu4.2_amd64.deb ...
# Unpacking libgpgme11:amd64 (1.16.0-1.2ubuntu4.2) ...
# Selecting previously unselected package libgpgmepp6:amd64.
# Preparing to unpack .../21-libgpgmepp6_1.16.0-1.2ubuntu4.2_amd64.deb ...
# Unpacking libgpgmepp6:amd64 (1.16.0-1.2ubuntu4.2) ...
# Selecting previously unselected package libharfbuzz-icu0:amd64.
# Preparing to unpack .../22-libharfbuzz-icu0_2.7.4-1ubuntu3.2_amd64.deb ...
# Unpacking libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.2) ...
# Selecting previously unselected package libhunspell-1.7-0:amd64.
# Preparing to unpack .../23-libhunspell-1.7-0_1.7.0-4build1_amd64.deb ...
# Unpacking libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Selecting previously unselected package libhyphen0:amd64.
# Preparing to unpack .../24-libhyphen0_2.8.8-7build2_amd64.deb ...
# Unpacking libhyphen0:amd64 (2.8.8-7build2) ...
# Selecting previously unselected package libmhash2:amd64.
# Preparing to unpack .../25-libmhash2_0.9.9.9-9build2_amd64.deb ...
# Unpacking libmhash2:amd64 (0.9.9.9-9build2) ...
# Selecting previously unselected package libmwaw-0.3-3:amd64.
# Preparing to unpack .../26-libmwaw-0.3-3_0.3.21-1build1_amd64.deb ...
# Unpacking libmwaw-0.3-3:amd64 (0.3.21-1build1) ...
# Selecting previously unselected package libmythes-1.2-0:amd64.
# Preparing to unpack .../27-libmythes-1.2-0_2%3a1.2.4-4build1_amd64.deb ...
# Unpacking libmythes-1.2-0:amd64 (2:1.2.4-4build1) ...
# Selecting previously unselected package libodfgen-0.1-1:amd64.
# Preparing to unpack .../28-libodfgen-0.1-1_0.1.8-2build2_amd64.deb ...
# Unpacking libodfgen-0.1-1:amd64 (0.1.8-2build2) ...
# Selecting previously unselected package liborcus-parser-0.17-0:amd64.
# Preparing to unpack .../29-liborcus-parser-0.17-0_0.17.2-2_amd64.deb ...
# Unpacking liborcus-parser-0.17-0:amd64 (0.17.2-2) ...
# Selecting previously unselected package liborcus-0.17-0:amd64.
# Preparing to unpack .../30-liborcus-0.17-0_0.17.2-2_amd64.deb ...
# Unpacking liborcus-0.17-0:amd64 (0.17.2-2) ...
# Selecting previously unselected package libyajl2:amd64.
# Preparing to unpack .../31-libyajl2_2.1.0-3ubuntu0.22.04.1_amd64.deb ...
# Unpacking libyajl2:amd64 (2.1.0-3ubuntu0.22.04.1) ...
# Selecting previously unselected package libraptor2-0:amd64.
# Preparing to unpack .../32-libraptor2-0_2.0.15-0ubuntu4_amd64.deb ...
# Unpacking libraptor2-0:amd64 (2.0.15-0ubuntu4) ...
# Selecting previously unselected package librasqal3:amd64.
# Preparing to unpack .../33-librasqal3_0.9.33-0.2ubuntu1_amd64.deb ...
# Unpacking librasqal3:amd64 (0.9.33-0.2ubuntu1) ...
# Selecting previously unselected package librdf0:amd64.
# Preparing to unpack .../34-librdf0_1.0.17-1.1ubuntu3_amd64.deb ...
# Unpacking librdf0:amd64 (1.0.17-1.1ubuntu3) ...
# Selecting previously unselected package libreoffice-style-colibre.
# Preparing to unpack .../35-libreoffice-style-colibre_1%3a7.3.7-0ubuntu0.22.04.8_all.deb ...
# Unpacking libreoffice-style-colibre (1:7.3.7-0ubuntu0.22.04.8) ...
# Selecting previously unselected package libuno-sal3.
# Preparing to unpack .../36-libuno-sal3_1%3a7.3.7-0ubuntu0.22.04.8_amd64.deb ...
# Unpacking libuno-sal3 (1:7.3.7-0ubuntu0.22.04.8) ...
# Selecting previously unselected package libuno-salhelpergcc3-3.
# Preparing to unpack .../37-libuno-salhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.8_amd64.deb ...
# Unpacking libuno-salhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.8) ...
# Selecting previously unselected package libuno-cppu3.
# Preparing to unpack .../38-libuno-cppu3_1%3a7.3.7-0ubuntu0.22.04.8_amd64.deb ...
# Unpacking libuno-cppu3 (1:7.3.7-0ubuntu0.22.04.8) ...
# Selecting previously unselected package uno-libs-private.
# Preparing to unpack .../39-uno-libs-private_1%3a7.3.7-0ubuntu0.22.04.8_amd64.deb ...
# Unpacking uno-libs-private (1:7.3.7-0ubuntu0.22.04.8) ...
# Selecting previously unselected package libuno-cppuhelpergcc3-3.
# Preparing to unpack .../40-libuno-cppuhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.8_amd64.deb ...
# Unpacking libuno-cppuhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.8) ...
# Selecting previously unselected package libuno-purpenvhelpergcc3-3.
# Preparing to unpack .../41-libuno-purpenvhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.8_amd64.deb ...
# Unpacking libuno-purpenvhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.8) ...
# Selecting previously unselected package ure.
# Preparing to unpack .../42-ure_1%3a7.3.7-0ubuntu0.22.04.8_amd64.deb ...
# Unpacking ure (1:7.3.7-0ubuntu0.22.04.8) ...
# Selecting previously unselected package libreoffice-common.
# Preparing to unpack .../43-libreoffice-common_1%3a7.3.7-0ubuntu0.22.04.8_all.deb ...
# Unpacking libreoffice-common (1:7.3.7-0ubuntu0.22.04.8) ...
# Selecting previously unselected package libxmlsec1:amd64.
# Preparing to unpack .../44-libxmlsec1_1.2.33-1build2_amd64.deb ...
# Unpacking libxmlsec1:amd64 (1.2.33-1build2) ...
# Selecting previously unselected package libxmlsec1-nss:amd64.
# Preparing to unpack .../45-libxmlsec1-nss_1.2.33-1build2_amd64.deb ...
# Unpacking libxmlsec1-nss:amd64 (1.2.33-1build2) ...
# Selecting previously unselected package libreoffice-core.
# Preparing to unpack .../46-libreoffice-core_1%3a7.3.7-0ubuntu0.22.04.8_amd64.deb ...
# Unpacking libreoffice-core (1:7.3.7-0ubuntu0.22.04.8) ...
# Selecting previously unselected package libreoffice-base-core.
# Preparing to unpack .../47-libreoffice-base-core_1%3a7.3.7-0ubuntu0.22.04.8_amd64.deb ...
# Unpacking libreoffice-base-core (1:7.3.7-0ubuntu0.22.04.8) ...
# Selecting previously unselected package libreoffice-math.
# Preparing to unpack .../48-libreoffice-math_1%3a7.3.7-0ubuntu0.22.04.8_amd64.deb ...
# Unpacking libreoffice-math (1:7.3.7-0ubuntu0.22.04.8) ...
# Selecting previously unselected package libwpd-0.10-10:amd64.
# Preparing to unpack .../49-libwpd-0.10-10_0.10.3-2build1_amd64.deb ...
# Unpacking libwpd-0.10-10:amd64 (0.10.3-2build1) ...
# Selecting previously unselected package libwpg-0.3-3:amd64.
# Preparing to unpack .../50-libwpg-0.3-3_0.3.3-1build3_amd64.deb ...
# Unpacking libwpg-0.3-3:amd64 (0.3.3-1build3) ...
# Selecting previously unselected package libwps-0.4-4:amd64.
# Preparing to unpack .../51-libwps-0.4-4_0.4.12-2build1_amd64.deb ...
# Unpacking libwps-0.4-4:amd64 (0.4.12-2build1) ...
# Selecting previously unselected package libreoffice-writer.
# Preparing to unpack .../52-libreoffice-writer_1%3a7.3.7-0ubuntu0.22.04.8_amd64.deb ...
# Unpacking libreoffice-writer (1:7.3.7-0ubuntu0.22.04.8) ...
# Selecting previously unselected package python3-uno.
# Preparing to unpack .../53-python3-uno_1%3a7.3.7-0ubuntu0.22.04.8_amd64.deb ...
# Unpacking python3-uno (1:7.3.7-0ubuntu0.22.04.8) ...
# Setting up libtext-iconv-perl (1.7-7build3) ...
# Setting up libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.2) ...
# Setting up libhyphen0:amd64 (2.8.8-7build2) ...
# Setting up dictionaries-common (1.28.14) ...
# Setting up libyajl2:amd64 (2.1.0-3ubuntu0.22.04.1) ...
# Setting up libuno-sal3 (1:7.3.7-0ubuntu0.22.04.8) ...
# Setting up libeot0:amd64 (0.01-5build2) ...
# Setting up libgpgme11:amd64 (1.16.0-1.2ubuntu4.2) ...
# Setting up librevenge-0.0-0:amd64 (0.0.4-6ubuntu7) ...
# Setting up poppler-data (0.4.11-1) ...
# Setting up apparmor (3.0.4-2ubuntu2.4) ...
# Created symlink /etc/systemd/system/sysinit.target.wants/apparmor.service → /lib/systemd/system/apparmor.service.
# Setting up libreoffice-style-colibre (1:7.3.7-0ubuntu0.22.04.8) ...
# Setting up liborcus-parser-0.17-0:amd64 (0.17.2-2) ...
# Setting up fonts-liberation2 (2.1.5-1) ...
# Setting up libclucene-core1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Setting up libabsl20210324:amd64 (0~20210324.2-2) ...
# Setting up libmhash2:amd64 (0.9.9.9-9build2) ...
# Setting up libmythes-1.2-0:amd64 (2:1.2.4-4build1) ...
# Setting up libexttextcat-data (3.4.5-1build2) ...
# Setting up libabw-0.1-1:amd64 (0.1.3-1build3) ...
# Setting up libepubgen-0.1-1:amd64 (0.1.1-1ubuntu5) ...
# Setting up hunspell-en-us (1:2020.12.07-2) ...
# Setting up libuno-salhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.8) ...
# Setting up liblangtag-common (0.6.3-2ubuntu1) ...
# Setting up libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Setting up libxmlsec1:amd64 (1.2.33-1build2) ...
# Setting up libwpd-0.10-10:amd64 (0.10.3-2build1) ...
# Setting up fonts-opensymbol (2:102.12+LibO7.3.7-0ubuntu0.22.04.8) ...
# Setting up libodfgen-0.1-1:amd64 (0.1.8-2build2) ...
# Setting up libwps-0.4-4:amd64 (0.4.12-2build1) ...
# Setting up libexttextcat-2.0-0:amd64 (3.4.5-1build2) ...
# Setting up libgpgmepp6:amd64 (1.16.0-1.2ubuntu4.2) ...
# Setting up libraptor2-0:amd64 (2.0.15-0ubuntu4) ...
# Setting up libmwaw-0.3-3:amd64 (0.3.21-1build1) ...
# Setting up liblangtag1:amd64 (0.6.3-2ubuntu1) ...
# Setting up liborcus-0.17-0:amd64 (0.17.2-2) ...
# Setting up libuno-cppu3 (1:7.3.7-0ubuntu0.22.04.8) ...
# Setting up libclucene-contribs1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Setting up libwpg-0.3-3:amd64 (0.3.3-1build3) ...
# Setting up libxmlsec1-nss:amd64 (1.2.33-1build2) ...
# Setting up libuno-purpenvhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.8) ...
# Setting up uno-libs-private (1:7.3.7-0ubuntu0.22.04.8) ...
# Setting up librasqal3:amd64 (0.9.33-0.2ubuntu1) ...
# Setting up libetonyek-0.1-1:amd64 (0.1.10-3build1) ...
# Setting up libe-book-0.1-1:amd64 (0.1.3-2build2) ...
# Setting up librdf0:amd64 (1.0.17-1.1ubuntu3) ...
# Setting up libuno-cppuhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.8) ...
# Setting up ure (1:7.3.7-0ubuntu0.22.04.8) ...
# Setting up libreoffice-common (1:7.3.7-0ubuntu0.22.04.8) ...
#
# Creating config file /etc/libreoffice/registry/main.xcd with new version
#
# Creating config file /etc/libreoffice/registry/pdfimport.xcd with new version
#
# Creating config file /etc/libreoffice/registry/xsltfilter.xcd with new version
#
# Creating config file /etc/libreoffice/registry/lingucomponent.xcd with new version
#
# Creating config file /etc/libreoffice/registry/Langpack-en-US.xcd with new version
#
# Creating config file /etc/libreoffice/registry/res/fcfg_langpack_en-US.xcd with new version
# Setting up libreoffice-core (1:7.3.7-0ubuntu0.22.04.8) ...
# Setting up libreoffice-math (1:7.3.7-0ubuntu0.22.04.8) ...
#
# Creating config file /etc/libreoffice/registry/math.xcd with new version
# Setting up libreoffice-base-core (1:7.3.7-0ubuntu0.22.04.8) ...
# Setting up python3-uno (1:7.3.7-0ubuntu0.22.04.8) ...
#
# Creating config file /etc/libreoffice/registry/pyuno.xcd with new version
# Setting up libreoffice-writer (1:7.3.7-0ubuntu0.22.04.8) ...
#
# Creating config file /etc/libreoffice/registry/writer.xcd with new version
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for shared-mime-info (2.1-2) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for dictionaries-common (1.28.14) ...

# %%
import fitz  # PyMuPDF
import requests
import tempfile
import os
import subprocess
from io import BytesIO
from PIL import Image


def docx_zu_bild(docx_url):
    """
    Lädt eine docx-Datei von einer URL herunter, konvertiert sie in PDF und dann in ein Bild.

    Args:
        docx_url (str): Die URL der docx-Datei.

    Returns:
        PIL.Image.Image: Ein PIL-Image-Objekt, das alle Seiten des PDFs enthält.
        Gibt None zurück, wenn ein Fehler auftritt.
    """
    try:
        # 1. docx herunterladen
        response = requests.get(docx_url, stream=True)
        response.raise_for_status()  # Sicherstellen, dass der Download erfolgreich war

        # Create a temporary file to store the downloaded docx
        with tempfile.NamedTemporaryFile(delete=False, suffix=".docx") as temp_docx:
            for chunk in response.iter_content(chunk_size=8192):
                temp_docx.write(chunk)
            temp_docx_path = temp_docx.name

        # 2. docx zu PDF konvertieren using libreoffice-writer
        pdf_path = os.path.splitext(temp_docx_path)[0] + ".pdf"
        subprocess.run(
            [
                "libreoffice",
                "--headless",
                "--convert-to",
                "pdf",
                "--outdir",
                os.path.dirname(pdf_path),
                temp_docx_path,
            ],
            check=True,
        )

        # 3. PDF zu Bild konvertieren (mit PyMuPDF für bessere Qualität)
        doc = fitz.open(pdf_path)
        seiten = []
        for seite in doc:
            pix = seite.get_pixmap()
            img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
            seiten.append(img)

        breite = max(img.width for img in seiten)
        hoehe = sum(img.height for img in seiten)
        gesamt_bild = Image.new("RGB", (breite, hoehe))

        aktuelle_hoehe = 0
        for img in seiten:
            gesamt_bild.paste(img, (0, aktuelle_hoehe))
            aktuelle_hoehe += img.height

        # Clean up temporary files
        os.remove(temp_docx_path)
        os.remove(pdf_path)

        return gesamt_bild

    except requests.exceptions.RequestException as e:
        print(f"Fehler beim Herunterladen der Datei: {e}")
        return None
    except Exception as e:
        print(f"Fehler bei der Konvertierung: {e}")
        return None

# %%
images: List[Image.Image] = [
    docx_zu_bild(
        "https://www.fluechtlinge-willkommen-in-duesseldorf.de/fileadmin/public/Redaktion/Bilder/Content/Asyl/asyl_leitfaden.2.muster-antrag-auf-zustimmung-zum-praktikum-mit-duldung.docx"
    ),
]
# NOTE: Because ColQWen2 uses dynamic resolution, we will scale down the images to prevent VRAM overload and faster
# inference times for both indexing and generation. From my experiments, a scale of 512 pixels is a good default for
# document tasks. Feel free to experiment with higher resolutions, especially if the text on your document is small.
#images = [scale_image(image, new_height=512) for image in images]

#for image in images:
display(images[0])
# Out:
# <PIL.Image.Image image mode=RGB size=596x842>

# %% [markdown]
# ## The `ColQwen2ForRAG` class

# %% [markdown]
# To simplify the usage of ColQwen2 for RAG, I have provided a `ColQwen2ForRAG` class that:
# - wraps the original `ColQwen2` model
# - hides the complexity behind adapter handling (the current version of PEFT is not always straightforward to use)
# - provides a simple API to switch between the retrieval and the generation modes.

# %%
class ColQwen2ForRAG(ColQwen2):
    """
    ColQwen2 model implementation that can be used both for retrieval and generation.
    Allows switching between retrieval and generation modes.
    """

    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self._is_retrieval_enabled = True

    def forward(self, *args, **kwargs) -> Any:
        """
        Forward pass that calls either Qwen2VLForConditionalGeneration.forward for generation
        or ColQwen2.forward for retrieval based on the current mode.
        """
        if self.is_retrieval_enabled:
            return ColQwen2.forward(self, *args, **kwargs)
        else:
            return Qwen2VLForConditionalGeneration.forward(self, *args, **kwargs)

    def generate(self, *args, **kwargs):
        """
        Generate text using Qwen2VLForConditionalGeneration.generate.
        """
        if not self.is_generation_enabled:
            raise ValueError(
                "Set the model to generation mode by calling `enable_generation()` before calling `generate()`."
            )
        return super().generate(*args, **kwargs)

    @property
    def is_retrieval_enabled(self) -> bool:
        return self._is_retrieval_enabled

    @property
    def is_generation_enabled(self) -> bool:
        return not self.is_retrieval_enabled

    def enable_retrieval(self) -> None:
        """
        Switch to retrieval mode.
        """
        self.enable_adapters()
        self._is_retrieval_enabled = True

    def enable_generation(self) -> None:
        """
        Switch to generation mode.
        """
        self.disable_adapters()
        self._is_retrieval_enabled = False

# %% [markdown]
# ## Load ColQwen2

# %% [markdown]
# Click on the following link to open the model card for [`vidore/colqwen2-v1.0`](https://huggingface.co/vidore/colqwen2-v1.0).

# %%
model_name = "vidore/colqwen2-v1.0"
device = get_torch_device("auto")

print(f"Using device: {device}")

# Get the LoRA config from the pretrained retrieval model
lora_config = LoraConfig.from_pretrained(model_name)

# Load the processors
processor_retrieval = cast(ColQwen2Processor, ColQwen2Processor.from_pretrained(model_name))
processor_generation = cast(Qwen2VLProcessor, Qwen2VLProcessor.from_pretrained(lora_config.base_model_name_or_path))

# Load the model with the loaded pre-trained adapter for retrieval
model = cast(
    ColQwen2ForRAG,
    ColQwen2ForRAG.from_pretrained(
        model_name,
        torch_dtype=torch.bfloat16,
        device_map=device,
    ),
)
# Out:
# Using device: cuda:0
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# adapter_config.json:   0%|          | 0.00/728 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/568 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/4.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/392 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/568 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/4.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/392 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/56.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.85G [00:00<?, ?B/s]
# `Qwen2VLRotaryEmbedding` can now be fully parameterized by passing the model config through the `config` argument. All other arguments will be removed in v4.46
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/220 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/74.0M [00:00<?, ?B/s]

# %% [markdown]
# Run the following cell to load the default query and image inputs. If you want to use your own image/query, upload your image in the Google Colab environment, then replace the following variable values with your own.
#
# The images represent your RAG corpus. For simplicity, we will use only 2 images in this example and ask the model to retrieve the most relevant one for the input query.

# %%
#images: List[Image.Image] = [
#    docx_zu_bild(
#        "https://www.fluechtlinge-willkommen-in-duesseldorf.de/fileadmin/public/Redaktion/Bilder/Content/Asyl/asyl_leitfaden.2.muster-antrag-auf-zustimmung-zum-praktikum-mit-duldung.docx"
#    ),
#
#]

#images: List[Image.Image] = [
#    load_image_from_url(
#        "https://www.fluechtlinge-willkommen-in-duesseldorf.de/fileadmin/public/Redaktion/Bilder/Content/Asyl/asyl_leitfaden.6.muster-ladung-zur-persoenlichen-anhoerung.PNG?raw=true"
#    ),
#    load_image_from_url(
#        "https://www.fluechtlinge-willkommen-in-duesseldorf.de/fileadmin/public/Redaktion/Bilder/Content/Asyl/asyl_leitfaden.7.muster-protokoll-ueber-persoenliche-anhoerung.PNG?raw=true"
#   ),
#    load_image_from_url(
#        "https://www.fluechtlinge-willkommen-in-duesseldorf.de/fileadmin/public/Redaktion/Bilder/Content/Asyl/asyl_leitfaden.8.muster-ablehnungsbescheid-wegen-dublin-verordnung.PNG?raw=true"
#    ),
#    load_image_from_url(
#        "https://www.fluechtlinge-willkommen-in-duesseldorf.de/fileadmin/public/Redaktion/Bilder/Content/Asyl/asyl_leitfaden.13.muster-ablehnung-eilantrag.PNG?raw=true"
#    ),
#    docx_zu_bild(
#        "https://www.fluechtlinge-willkommen-in-duesseldorf.de/fileadmin/public/Redaktion/Bilder/Content/Asyl/asyl_leitfaden.2.muster-antrag-auf-zustimmung-zum-praktikum-mit-duldung.docx"
#    ),
#]

# NOTE: Because ColQWen2 uses dynamic resolution, we will scale down the images to prevent VRAM overload and faster
# inference times for both indexing and generation. From my experiments, a scale of 512 pixels is a good default for
# document tasks. Feel free to experiment with higher resolutions, especially if the text on your document is small.
images = [scale_image(image, new_height=512) for image in images]

for image in images:
    display(scale_image(image, new_height=256))
# Out:
# <PIL.Image.Image image mode=RGB size=181x256>

# %% [markdown]
# ## Part 1 of RAG: Retrieval

# %% [markdown]
# This is the retrieval part of the RAG. In this example, we only keep the top-1 result for demonstration purposes.
#
# In practice, using more results (e.g., top-5) can improve the quality of the final answer.

# %%
# Inputs
# query = "Was muss bei beim Dublinverfahren mitgebracht werden?"
# query = "Wann ist der persönliche Termin zum Dublinverfahren?"
# query = "Was ist die Entscheidung des Gerichts?"

query = "Antrag auf Erteilung der Zustimmung für ein Praktikum mit Duldung ?"

# Process the inputs
batch_images = processor_retrieval.process_images(images).to(model.device)
batch_queries = processor_retrieval.process_queries([query]).to(model.device)

# Forward pass
model.enable_retrieval()

with torch.no_grad():
    image_embeddings = model.forward(**batch_images)
    query_embeddings = model.forward(**batch_queries)

# Calculate the similarity scores
scores = processor_retrieval.score_multi_vector(query_embeddings, image_embeddings)

# Get the top-1 page image
retrieved_image_index = scores.argmax().item()
retrieved_image = images[retrieved_image_index]

print(f"Image retrieved for the following query: `{query}`")
display(scale_image(retrieved_image, new_height=256))
# Out:
# Image retrieved for the following query: `Antrag auf Erteilung der Zustimmung für ein Praktikum mit Duldung ?`
# <PIL.Image.Image image mode=RGB size=181x256>

# %% [markdown]
# ## Part 2 of RAG: Augmented Generation

# %% [markdown]
# Now comes the generation part of the RAG. Using the retrieved image from the retrieval part, we will disable the retrieval adapter in ColQwen2 to use its Qwen2-VL VLM backbone to generate the answer based on both the query and the retrieved image.

# %%
# Preprocess the inputs
conversation = [
    {
        "role": "user",
        "content": [
            {
                "type": "image",
            },
            {
                "type": "text",
                "text": f"Answer the following question using the input image in the language German: {query}",
            },
        ],
    }
]
text_prompt = processor_generation.apply_chat_template(conversation, add_generation_prompt=True)
inputs_generation = processor_generation(
    text=[text_prompt],
    images=[retrieved_image],
    padding=True,
    return_tensors="pt",
).to(device)

# Generate the RAG response
model.enable_generation()
output_ids = model.generate(**inputs_generation, max_new_tokens=128)

# Ensure that only the newly generated token IDs are retained from output_ids
generated_ids = [output_ids[len(input_ids) :] for input_ids, output_ids in zip(inputs_generation.input_ids, output_ids)]

display(scale_image(retrieved_image, new_height=256))

# Decode the RAG response
output_text = processor_generation.batch_decode(
    generated_ids,
    skip_special_tokens=True,
    clean_up_tokenization_spaces=True,
)

print(output_text)
# Out:
# <PIL.Image.Image image mode=RGB size=181x256>
# ['Ja, der Antrag auf Erteilung der Zustimmung für ein Praktikum mit Duldung wurde an 01.08.2019 gestellt.']

# %%
query = """Wer hat den Antrag gestellt? Bitte verwende nur die Angaben im Briefkop. Bitte gebe die Daten in einer normierten Form der Postanschrift aus. Fehlende Angaben sollen mit XXX ausgegeben werden.     """
# Process the inputs
batch_images = processor_retrieval.process_images(images).to(model.device)
batch_queries = processor_retrieval.process_queries([query]).to(model.device)

# Forward pass
model.enable_retrieval()

with torch.no_grad():
    image_embeddings = model.forward(**batch_images)
    query_embeddings = model.forward(**batch_queries)

# Calculate the similarity scores
scores = processor_retrieval.score_multi_vector(query_embeddings, image_embeddings)

# Get the top-1 page image
retrieved_image_index = scores.argmax().item()
retrieved_image = images[retrieved_image_index]

print(f"Image retrieved for the following query: `{query}`")
display(scale_image(retrieved_image, new_height=256))


# Preprocess the inputs
conversation = [
    {
        "role": "user",
        "content": [
            {
                "type": "image",
            },
            {
                "type": "text",
                "text": f"Answer the following question using the input image and answer in German: {query}",
            },
        ],
    }
]
text_prompt = processor_generation.apply_chat_template(conversation, add_generation_prompt=True)
inputs_generation = processor_generation(
    text=[text_prompt],
    images=[retrieved_image],
    padding=True,
    return_tensors="pt",
).to(device)

# Generate the RAG response
model.enable_generation()
output_ids = model.generate(**inputs_generation, max_new_tokens=256) #max_new_tokens=128

# Ensure that only the newly generated token IDs are retained from output_ids
generated_ids = [output_ids[len(input_ids) :] for input_ids, output_ids in zip(inputs_generation.input_ids, output_ids)]

# Decode the RAG response
output_text = processor_generation.batch_decode(
    generated_ids,
    skip_special_tokens=True,
    clean_up_tokenization_spaces=True,
)

print(output_text)
# Out:
# Image retrieved for the following query: `Wer hat den Antrag gestellt? Bitte verwende nur die Angaben im Briefkop. Bitte gebe die Daten in einer normierten Form der Postanschrift aus. Fehlende Angaben sollen mit XXX ausgegeben werden.     `
# <PIL.Image.Image image mode=RGB size=181x256>
# ['Müllerweg 1 30000 Hannover']

# %% [markdown]
# If you look closely at the input image, you will see that the model has correctly answered the user query! 🙌🏼

# %%
query = "Wann findet der Termin zum Dublinverfahren mit Angabe von 'Datum' '_' um 'Uhrzeit' '_' statt, und wo 'Dienstgebäude:' '_', 'Straße:' '_' )?"
# Process the inputs
batch_images = processor_retrieval.process_images(images).to(model.device)
batch_queries = processor_retrieval.process_queries([query]).to(model.device)

# Forward pass
model.enable_retrieval()

with torch.no_grad():
    image_embeddings = model.forward(**batch_images)
    query_embeddings = model.forward(**batch_queries)

# Calculate the similarity scores
scores = processor_retrieval.score_multi_vector(query_embeddings, image_embeddings)

# Get the top-1 page image
retrieved_image_index = scores.argmax().item()
retrieved_image = images[retrieved_image_index]

print(f"Image retrieved for the following query: `{query}`")
display(scale_image(retrieved_image, new_height=256))


# Preprocess the inputs
conversation = [
    {
        "role": "user",
        "content": [
            {
                "type": "image",
            },
            {
                "type": "text",
                "text": f"Answer the following question using the input image and answer in German: {query}",
            },
        ],
    }
]
text_prompt = processor_generation.apply_chat_template(conversation, add_generation_prompt=True)
inputs_generation = processor_generation(
    text=[text_prompt],
    images=[retrieved_image],
    padding=True,
    return_tensors="pt",
).to(device)

# Generate the RAG response
model.enable_generation()
output_ids = model.generate(**inputs_generation, max_new_tokens=128)

# Ensure that only the newly generated token IDs are retained from output_ids
generated_ids = [output_ids[len(input_ids) :] for input_ids, output_ids in zip(inputs_generation.input_ids, output_ids)]

# Decode the RAG response
output_text = processor_generation.batch_decode(
    generated_ids,
    skip_special_tokens=True,
    clean_up_tokenization_spaces=True,
)

print(output_text)
# Out:
# Image retrieved for the following query: `Wann findet der Termin zum Dublinverfahren mit Angabe von 'Datum' '_' um 'Uhrzeit' '_' statt, und wo 'Dienstgebäude:' '_', 'Straße:' '_' )?`
# <PIL.Image.Image image mode=RGBA size=183x256>
# ['Der Termin zum Dublinverfahren findet am 09.11.2018 um 08:30 Uhr im Dienstgebäude 2663 Bad Fallingsbostel statt.']

# %%
query = "Wer ist der Absender als 'Hausanschrift' und Straße '_'  und Zip Code / Ort '_', und wie lautet die Telefonnummer '_', und Faxnummer '_')?"

# Preprocess the inputs
conversation = [
    {
        "role": "user",
        "content": [
            {
                "type": "image",
            },
            {
                "type": "text",
                "text": f"Answer the following question using the input image and answer in German: {query}",
            },
        ],
    }
]
text_prompt = processor_generation.apply_chat_template(conversation, add_generation_prompt=True)
inputs_generation = processor_generation(
    text=[text_prompt],
    images=[retrieved_image],
    padding=True,
    return_tensors="pt",
).to(device)

# Generate the RAG response
model.enable_generation()
output_ids = model.generate(**inputs_generation, max_new_tokens=128)

# Ensure that only the newly generated token IDs are retained from output_ids
generated_ids = [output_ids[len(input_ids) :] for input_ids, output_ids in zip(inputs_generation.input_ids, output_ids)]

display(scale_image(retrieved_image, new_height=256))

# Decode the RAG response
output_text = processor_generation.batch_decode(
    generated_ids,
    skip_special_tokens=True,
    clean_up_tokenization_spaces=True,
)


print(output_text)
# Out:
# <PIL.Image.Image image mode=RGBA size=183x256>
# ['Der Absender ist Harterer Straße 7, 2663 Bad Fallingbostel, mit der Telefonnummer 01194320000 und Faxnummer 01194320589.']

# %%
# Out:
# ['Die Niederschrift handelt um die Anhörung zur Zulässigkeit des Asylantrags gemäß § 29 Abs. 1 Nr. 1-4 AsylG i.V.m. § 25 Abs. 1 Satz 2 und Abs. 2 AsylG am 09.11.2018 in Bad Fallingbostel.']

# %% [markdown]
# **Scan-Quality Check:** Nun ein Versuch die im Scan die nicht lesbaren Informationen wie Bankverbindung auszulesen.

# %%
query = "Was ist die Bankverbindung: Kontoinhaber, IBAN und BIC?"

# Preprocess the inputs
conversation = [
    {
        "role": "user",
        "content": [
            {
                "type": "image",
            },
            {
                "type": "text",
                "text": f"Answer the following question using the input image and the info in the footer and answer in German: {query}",
            },
        ],
    }
]
text_prompt = processor_generation.apply_chat_template(conversation, add_generation_prompt=True)
inputs_generation = processor_generation(
    text=[text_prompt],
    images=[retrieved_image],
    padding=True,
    return_tensors="pt",
).to(device)

# Generate the RAG response
model.enable_generation()
output_ids = model.generate(**inputs_generation, max_new_tokens=512)

# Ensure that only the newly generated token IDs are retained from output_ids
generated_ids = [output_ids[len(input_ids) :] for input_ids, output_ids in zip(inputs_generation.input_ids, output_ids)]

display(scale_image(retrieved_image, new_height=512))

# Decode the RAG response
output_text = processor_generation.batch_decode(
    generated_ids,
    skip_special_tokens=False,
    clean_up_tokenization_spaces=True,
)

print(output_text)
# Out:
# <PIL.Image.Image image mode=RGBA size=366x512>
# ['Die Bankverbindung lautet: Kontoinhaber als Text, IBAN und BIC sind nicht angegeben.<|im_end|>']

# %% [markdown]
# ## 🙋🏻 Reminder
# If you want to re-run retrieval after this cell, make sure to use `model.enable_retrieval()` before `model.forward(...)`!

# %% [markdown]
# ## Additional notes
#
# - Try to rerun the previous cells but with the following query instead: `"Which hour of the day had the highest overall electricity generation in 2019?"`. You will see that ColQwen2 is capable of retrieving the correct page, but you should get an hallucinated answer for the generation part. As explained in one of the first sections, this is because [Qwen2-VL-2B](https://huggingface.co/Qwen/Qwen2-VL-2B-Instruct) has only a "small" number of parameters, which limits its chart understanding compared to its larger [12B](https://huggingface.co/Qwen/Qwen2-VL-7B-Instruct) and [72B](https://huggingface.co/Qwen/Qwen2-VL-72B-Instruct) counterparts.
# - While our [ColPali](https://huggingface.co/vidore/colpali-v1.3) model was also trained using a LoRA adapter, I do not recommend using it for E2E RAG as the PaliGemma VLM backbone can only take one image input at a time. Consequently, your RAG pipeline will only be capble of using a top-1 page context for generation, which will likely lead to suboptimal results.

# %%
# Out:
# ['Die Niederschrift handelt um die Anhörung zur Zulässigkeit des Asylantrags gemäß § 29 Abs. 1 Nr. 1-4 AsylG i.V.m. § 25 Abs. 1 Satz 2 und Abs. 2 AsylG am 09.11.2018 in Bad Fallingbostel.']
